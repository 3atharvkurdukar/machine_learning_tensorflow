# %% [markdown]
# # TensorFlow HelloWorld
# This is the most basic program using TensorFlow, thus named as "Hello World!" program of TensorFlow.

# %% [markdown]
# ## 1. Install TensorFlow 2.0
# This program makes use of TensorFlow v2.0.0-rc0. Make sure it is installed on your system

# %%
try:
    # %tensorflow_version 2.x
except Exception:
    # !pip install tensorflow==2.0.0-rc0

# %% [markdown]
# ## 2. Import the TensorFlow Library

# %%
import tensorflow as tf

# %% [markdown]
# ## 3. Load the MNIST Dataset
# The MNIST database of handwritten digits, available from this page, has a training set of 60,000 examples, and a test set of 10,000 examples. It is a subset of a larger set available from NIST. The digits have been size-normalized and centered in a fixed-size image.
#
# Once loaded, the inputs are converted from integers to floating-point numbers.

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## 4. Build the Model
# Build the `tf.keras.Sequential` model by stacking layers. Choose an optimizer and loss function for training:

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),  # Hidden Layer
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax') # Output Layer
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 5. Train and Evaluate the Model

# %%
model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2993 - accuracy: 0.9125
# Epoch 2/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1455 - accuracy: 0.9565
# Epoch 3/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1077 - accuracy: 0.9675
# Epoch 4/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0886 - accuracy: 0.9721
# Epoch 5/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0760 - accuracy: 0.9757
# Epoch 6/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0673 - accuracy: 0.9786
# Epoch 7/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0574 - accuracy: 0.9815
# Epoch 8/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0545 - accuracy: 0.9821
# Epoch 9/10
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
